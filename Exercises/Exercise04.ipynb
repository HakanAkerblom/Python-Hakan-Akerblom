# %%
# 1. Dice rolls

import random

kast = [random.randint(1,6) for i in range(10)]
kast.sort()
print(kast)
kast.reverse()
print(kast)
print(max(kast))
print(min(kast))
# Out:
# [1, 1, 2, 2, 3, 3, 4, 4, 5, 6]
# [6, 5, 4, 4, 3, 3, 2, 2, 1, 1]
# 6
# 1

# %%
# 2. Food menu

foods = ["vegetarisk lasagne", "spaghetti", "fisk", "görnsakssoppa", "pannkakor"]
weekdays = ["Må", "Ti", "On", "To", "Fr", "Lö", "Sö"]
food_menu = "Food Menu \n"

for food, day in zip(foods, weekdays):
    food_menu += f"{day}: {food}\n"
print(food_menu)
# Out:
# Food Menu
# Må: vegetarisk lasagne
# Ti: spaghetti
# On: fisk
# To: görnsakssoppa
# Fr: pannkakor

# %%
# 3. Squares
import matplotlib.pyplot as plt

squares = [i**2 for i in range(-10, 11)]
print(squares)

plt.plot(squares)
# Out:
# [100, 81, 64, 49, 36, 25, 16, 9, 4, 1, 0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
# 4. Chessboard

alfabet = "ABCDEFGH"
chessboard = []
for row in range(1,9):
    my_list = [alfabet[i]+str(row) for i in range(8)]
    chessboard.append(my_list)

# print(chessboard)

for i in range(8):
    print(chessboard[i])
# Out:
# ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']
# ['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2']
# ['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3']
# ['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4']
# ['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5']
# ['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6']
# ['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7']
# ['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8']

# %%
# 5. Dice rolls convergence
import random
import matplotlib.pyplot as plt

probs =[]
for i in range(1,7):
    rolls = [random.randint(1,6) for _ in range(10**i)]
    prob = rolls.count(6)/(10**i)
    probs.append(prob)
print(probs)

plt.plot(probs, "-*")
plt.xticks([0,1,2,3,4,5], [10, 100, 1000, 10000, 100000, 1000000])
plt.title("Andel sexor för olika tärningsslag")
plt.xlabel("Antal tärningsslag")
plt.ylabel("Andel sexor");
# Out:
# [0.2, 0.06, 0.17, 0.1672, 0.16623, 0.166961]

# %%
# 6. Monte Carlo Simulation
import random
import math
import matplotlib.pyplot as plt
reds = 0
blues = 0

for i in range(5000):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    if math.sqrt(x**2+y**2)>1:
        color = "ro"
        reds += 1
    else:
        color = "bo"
        blues += 1
    plt.plot(x, y, color)

print(blues/(blues+reds))
print(math.pi/4)
# Out:
# 0.7786
# 0.7853981633974483

# %%
# A cute rabbit among two ferocious snakes
import random
import matplotlib.pyplot as plt

rabbits_switch = [0, 0, 0, 0, 0, 0]
rabbits_stay = [0, 0, 0, 0, 0, 0]
for n in range(6):
    for i in range(10**n):
        doors = ["snake", "snake", "snake"]
        correct_guess = random.randint(0, 2)
        doors[correct_guess] = "rabbit"
        my_guess = random.randint(0, 2)
        if my_guess != correct_guess:
            rabbits_switch[n] += 1

for n in range(6):
    for i in range(10**n):
        doors = ["snake", "snake", "snake"]
        correct_guess = random.randint(0, 2)
        doors[correct_guess] = "rabbit"
        my_guess = random.randint(0, 2)
        if my_guess == correct_guess:
            rabbits_stay[n] += 1

print(f"{rabbits_switch=}")
print(f"{rabbits_stay=}")

prob_switch = [rabbits_switch[i]/10**i for i in range(6)]
print(f"{prob_switch=}")
prob_stay = [rabbits_stay[i]/10**i for i in range(6)]
print(f"{prob_stay=}")

plt.plot(prob_stay, label="stay")
plt.plot(prob_switch, label="switch")
plt.xticks([0,1,2,3,4,5], [1, 10, 100, 1000, 10000, 100000])
plt.ylabel("Andel kaniner")
plt.xlabel("Antal försök")
plt.legend(loc="upper right")
plt.title("Andel kaniner beroende på strategi")
# Out:
# rabbits_switch=[1, 7, 70, 675, 6651, 66424]
# rabbits_stay=[1, 3, 30, 352, 3330, 33018]
# prob_switch=[1.0, 0.7, 0.7, 0.675, 0.6651, 0.66424]
# prob_stay=[1.0, 0.3, 0.3, 0.352, 0.333, 0.33018]
# Text(0.5, 1.0, 'Andel kaniner beroende på strategi')
