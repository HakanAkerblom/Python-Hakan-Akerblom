# %%
from __future__ import annotations
import sys, os
import unittest


# we define a path that is up one step
# in this pathwe have vecot.py and plotter.py and 
# manual_testing.ipynb
path_to_geometry_module = "c:/Users/hakan/Documents/Programmering/Github/Python-Hakan-Akerblom/Labs/Lab3"

sys.path.append(path_to_geometry_module)
print("-"*30)
print(path_to_geometry_module)

from geometry import *

a = Rect(0, 0, 1, 1)
a.plot()
# Out:
# ------------------------------
# c:/Users/hakan/Documents/Programmering/Github/Python-Hakan-Akerblom/Labs/Lab3
