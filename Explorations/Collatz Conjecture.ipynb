# %%
# Standard Collatz, user input

i = int(input("Type starting value"))

while True:
    if i % 2 == 0:
        print(i, end = " -> ")
        i = int(i/2)
    elif i == 1:
        print(i)
        break
    else:
        print(i, end = " -> ")
        i = i*3+1
# Out:
# 27 -> 82 -> 41 -> 124 -> 62 -> 31 -> 94 -> 47 -> 142 -> 71 -> 214 -> 107 -> 322 -> 161 -> 484 -> 242 -> 121 -> 364 -> 182 -> 91 -> 274 -> 137 -> 412 -> 206 -> 103 -> 310 -> 155 -> 466 -> 233 -> 700 -> 350 -> 175 -> 526 -> 263 -> 790 -> 395 -> 1186 -> 593 -> 1780 -> 890 -> 445 -> 1336 -> 668 -> 334 -> 167 -> 502 -> 251 -> 754 -> 377 -> 1132 -> 566 -> 283 -> 850 -> 425 -> 1276 -> 638 -> 319 -> 958 -> 479 -> 1438 -> 719 -> 2158 -> 1079 -> 3238 -> 1619 -> 4858 -> 2429 -> 7288 -> 3644 -> 1822 -> 911 -> 2734 -> 1367 -> 4102 -> 2051 -> 6154 -> 3077 -> 9232 -> 4616 -> 2308 -> 1154 -> 577 -> 1732 -> 866 -> 433 -> 1300 -> 650 -> 325 -> 976 -> 488 -> 244 -> 122 -> 61 -> 184 -> 92 -> 46 -> 23 -> 70 -> 35 -> 106 -> 53 -> 160 -> 80 -> 40 -> 20 -> 10 -> 5 -> 16 -> 8 -> 4 -> 2 -> 1

# %%
# Calulating stopping time

import matplotlib.pyplot as plt
maximum = 1000000
count_list = []
for j in range(1, maximum):
    count = 0
    i = j
    while True:
        if i % 2 == 0:
            i = int(i/2)
            count += 1
        elif i == 1:
            count += 1
            break
        else:
            i = i*3+1
            count += 1
    count_list.append(count)
plt.plot(range(1, maximum), count_list, "o")
plt.title("Stopping time for Collatz Conjecture")
plt.xlabel("Starting value")
plt.ylabel("Number of iterations");

print(count_list.index(max(count_list)))
# Out:
# 837798

# %%
# Maximum value
maximum = 5000
maximums = []

for i in range(1, maximum):
    temp = []
    while True:
        if i % 2 == 0:
            temp.append(i)
            i = int(i/2)
        elif i == 1:
            temp.append(i)
            break
        else:
            temp.append(i)
            i = i*3+1
    maximums.append(max(temp))
plt.scatter(range(1, maximum), maximums, s=0.5)
plt.ylim([0, 9500])
# Out:
# (0.0, 9500.0)
